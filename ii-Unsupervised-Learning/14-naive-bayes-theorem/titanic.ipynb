# %% [markdown]
# ![](BayesTheorem.png)

# %% [markdown]
# ### The above is called the Bayes Theorem

# %% [markdown]
# ![](TitanicBayes.png)

# %% [markdown]
# ##### The above is a coditional probability where it is basically shown that we need to find the probability of survival based on certain conditions such as Gende, Class, Age, Cabin, Fare. This is a case of conditonal probability.

# %% [markdown]
# ##### We call this a naive bayes, because we make a naive assumption that these features, as in gender, class, age etc are independent of each other.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline 

COLOR = 'white'
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR

pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.options.display.float_format = '{:,.2f}'.format

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId                                               Name  Pclass  \
# 0            1                            Braund, Mr. Owen Harris       3
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2            3                             Heikkinen, Miss. Laina       3
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4            5                           Allen, Mr. William Henry       3
#
#       Sex   Age  SibSp  Parch            Ticket  Fare Cabin Embarked  Survived
# 0    male 22.00      1      0         A/5 21171  7.25   NaN        S         0
# 1  female 38.00      1      0          PC 17599 71.28   C85        C         1
# 2  female 26.00      0      0  STON/O2. 3101282  7.92   NaN        S         1
# 3  female 35.00      1      0            113803 53.10  C123        S         1
# 4    male 35.00      0      0            373450  8.05   NaN        S         0

# %%
df.drop(['PassengerId', 'Name', 'Parch', 'Cabin', 'Ticket', 'Embarked'], axis='columns', inplace=True)
df
# Out:
#      Pclass     Sex   Age  SibSp  Fare  Survived
# 0         3    male 22.00      1  7.25         0
# 1         1  female 38.00      1 71.28         1
# 2         3  female 26.00      0  7.92         1
# 3         1  female 35.00      1 53.10         1
# 4         3    male 35.00      0  8.05         0
# ..      ...     ...   ...    ...   ...       ...
# 886       2    male 27.00      0 13.00         0
# 887       1  female 19.00      0 30.00         1
# 888       3  female   NaN      1 23.45         0
# 889       1    male 26.00      0 30.00         1
# 890       3    male 32.00      0  7.75         0
#
# [891 rows x 6 columns]

# %%
dummies = pd.get_dummies(inputs.Sex)
dummies.head()
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1

# %%
inputs = pd.concat([inputs, dummies], axis='columns')

# %%
inputs.drop('Sex', inplace=True, axis='columns')
inputs
# Out:
#      Pclass   Age  SibSp  Fare  female  male
# 0         3 22.00      1  7.25       0     1
# 1         1 38.00      1 71.28       1     0
# 2         3 26.00      0  7.92       1     0
# 3         1 35.00      1 53.10       1     0
# 4         3 35.00      0  8.05       0     1
# ..      ...   ...    ...   ...     ...   ...
# 886       2 27.00      0 13.00       0     1
# 887       1 19.00      0 30.00       1     0
# 888       3   NaN      1 23.45       1     0
# 889       1 26.00      0 30.00       0     1
# 890       3 32.00      0  7.75       0     1
#
# [891 rows x 6 columns]

# %%
inputs.columns[inputs.isna().any()]
# inputs.Age[inputs['Age'] == 'NaN']
inputs.Age = inputs.Age.fillna(inputs.Age.mean(), inplace=True)
inputs.head()
# Out:
#    Pclass     Sex   Age  SibSp  Fare
# 0       3    male  None      1  7.25
# 1       1  female  None      1 71.28
# 2       3  female  None      0  7.92
# 3       1  female  None      1 53.10
# 4       3    male  None      0  8.05

# %%
target = df.Survived
inputs = df.drop('Survived', axis='columns')

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(inputs, target, test_size=0.2)

inputs
# Out:
#      Pclass     Sex   Age  SibSp  Fare
# 0         3    male 22.00      1  7.25
# 1         1  female 38.00      1 71.28
# 2         3  female 26.00      0  7.92
# 3         1  female 35.00      1 53.10
# 4         3    male 35.00      0  8.05
# ..      ...     ...   ...    ...   ...
# 886       2    male 27.00      0 13.00
# 887       1  female 19.00      0 30.00
# 888       3  female   NaN      1 23.45
# 889       1    male 26.00      0 30.00
# 890       3    male 32.00      0  7.75
#
# [891 rows x 5 columns]

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()
model.fit(X_train, y_train)
model.score
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12524/3489299122.py in <module>
#       2
#       3 model = GaussianNB()
# ----> 4 model.fit(X_train, y_train)
#       5 model.score
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     243         """
#     244         y = self._validate_data(y=y)
# --> 245         return self._partial_fit(
#     246             X, y, np.unique(y), _refit=True, sample_weight=sample_weight
#     247         )
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\naive_bayes.py in _partial_fit(self, X, y, classes, _refit, sample_weight)
#     400
#     401         first_call = _check_partial_fit_first_call(self, classes)
# --> 402         X, y = self._validate_data(X, y, reset=first_call)
# ...

# %%
# for i in inputs.female:
#     print(type(i))

inputs
# Out:
#      Pclass     Sex   Age  SibSp  Fare
# 0         3    male 22.00      1  7.25
# 1         1  female 38.00      1 71.28
# 2         3  female 26.00      0  7.92
# 3         1  female 35.00      1 53.10
# 4         3    male 35.00      0  8.05
# ..      ...     ...   ...    ...   ...
# 886       2    male 27.00      0 13.00
# 887       1  female 19.00      0 30.00
# 888       3  female   NaN      1 23.45
# 889       1    male 26.00      0 30.00
# 890       3    male 32.00      0  7.75
#
# [891 rows x 5 columns]
