# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline 

COLOR = 'white'
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR

pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ![](fitting.png)

# %%
df = pd.read_csv('Melbourne_housing_FULL.csv')
df
# Out:
#            Suburb             Address  Rooms Type        Price Method  \
# 0      Abbotsford       68 Studley St      2    h          NaN     SS
# 1      Abbotsford        85 Turner St      2    h 1,480,000.00      S
# 2      Abbotsford     25 Bloomburg St      2    h 1,035,000.00      S
# 3      Abbotsford  18/659 Victoria St      3    u          NaN     VB
# 4      Abbotsford        5 Charles St      3    h 1,465,000.00     SP
# ...           ...                 ...    ...  ...          ...    ...
# 34852  Yarraville         13 Burns St      4    h 1,480,000.00     PI
# 34853  Yarraville       29A Murray St      2    h   888,000.00     SP
# 34854  Yarraville      147A Severn St      2    t   705,000.00      S
# 34855  Yarraville    12/37 Stephen St      3    h 1,140,000.00     SP
# 34856  Yarraville    3 Tarrengower St      2    h 1,020,000.00     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis   3/09/2016      2.50  3,067.00  ...      1.00 1.00
# 1             Biggin   3/12/2016      2.50  3,067.00  ...      1.00 1.00
# 2             Biggin   4/02/2016      2.50  3,067.00  ...      1.00 0.00
# 3             Rounds   4/02/2016      2.50  3,067.00  ...      2.00 1.00
# 4             Biggin   4/03/2017      2.50  3,067.00  ...      2.00 0.00
# ...              ...         ...       ...       ...  ...       ...  ...
# 34852            Jas  24/02/2018      6.30  3,013.00  ...      1.00 3.00
# 34853        Sweeney  24/02/2018      6.30  3,013.00  ...      2.00 1.00
# 34854            Jas  24/02/2018      6.30  3,013.00  ...      1.00 2.00
# 34855  hockingstuart  24/02/2018      6.30  3,013.00  ...       NaN  NaN
# 34856             RW  24/02/2018      6.30  3,013.00  ...      1.00 0.00
#
#        Landsize  BuildingArea  YearBuilt               CouncilArea Lattitude  \
# 0        126.00           NaN        NaN        Yarra City Council    -37.80
# 1        202.00           NaN        NaN        Yarra City Council    -37.80
# 2        156.00         79.00   1,900.00        Yarra City Council    -37.81
# 3          0.00           NaN        NaN        Yarra City Council    -37.81
# 4        134.00        150.00   1,900.00        Yarra City Council    -37.81
# ...         ...           ...        ...                       ...       ...
# 34852    593.00           NaN        NaN  Maribyrnong City Council    -37.81
# 34853     98.00        104.00   2,018.00  Maribyrnong City Council    -37.82
# 34854    220.00        120.00   2,000.00  Maribyrnong City Council    -37.82
# 34855       NaN           NaN        NaN  Maribyrnong City Council       NaN
# 34856    250.00        103.00   1,930.00  Maribyrnong City Council    -37.82
#
#        Longtitude             Regionname Propertycount
# 0          145.00  Northern Metropolitan      4,019.00
# 1          145.00  Northern Metropolitan      4,019.00
# 2          144.99  Northern Metropolitan      4,019.00
# 3          145.01  Northern Metropolitan      4,019.00
# 4          144.99  Northern Metropolitan      4,019.00
# ...           ...                    ...           ...
# 34852      144.88   Western Metropolitan      6,543.00
# 34853      144.89   Western Metropolitan      6,543.00
# 34854      144.88   Western Metropolitan      6,543.00
# 34855         NaN   Western Metropolitan      6,543.00
# 34856      144.89   Western Metropolitan      6,543.00
#
# [34857 rows x 21 columns]

# %%
df.nunique()
# Out:
# Suburb             351
# Address          34009
# Rooms               12
# Type                 3
# Price             2871
# Method               9
# SellerG            388
# Date                78
# Distance           215
# Postcode           211
# Bedroom2            15
# Bathroom            11
# Car                 15
# Landsize          1684
# BuildingArea       740
# YearBuilt          160
# CouncilArea         33
# Lattitude        13402
# Longtitude       14524
# Regionname           8
# Propertycount      342
# dtype: int64

# %%
df.shape
# Out:
# (34857, 21)

# %%
# let's use limited columns which makes more sense for serving our purpose
cols_to_use = ['Suburb', 'Rooms', 'Type', 'Method', 'SellerG', 'Regionname', 'Propertycount', 
               'Distance', 'CouncilArea', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'Price']
df = df[cols_to_use]

# %%
df
# Out:
#            Suburb  Rooms Type Method        SellerG             Regionname  \
# 0      Abbotsford      2    h     SS         Jellis  Northern Metropolitan
# 1      Abbotsford      2    h      S         Biggin  Northern Metropolitan
# 2      Abbotsford      2    h      S         Biggin  Northern Metropolitan
# 3      Abbotsford      3    u     VB         Rounds  Northern Metropolitan
# 4      Abbotsford      3    h     SP         Biggin  Northern Metropolitan
# ...           ...    ...  ...    ...            ...                    ...
# 34852  Yarraville      4    h     PI            Jas   Western Metropolitan
# 34853  Yarraville      2    h     SP        Sweeney   Western Metropolitan
# 34854  Yarraville      2    t      S            Jas   Western Metropolitan
# 34855  Yarraville      3    h     SP  hockingstuart   Western Metropolitan
# 34856  Yarraville      2    h     PI             RW   Western Metropolitan
#
#        Propertycount  Distance               CouncilArea  Bedroom2  Bathroom  \
# 0           4,019.00      2.50        Yarra City Council      2.00      1.00
# 1           4,019.00      2.50        Yarra City Council      2.00      1.00
# 2           4,019.00      2.50        Yarra City Council      2.00      1.00
# 3           4,019.00      2.50        Yarra City Council      3.00      2.00
# 4           4,019.00      2.50        Yarra City Council      3.00      2.00
# ...              ...       ...                       ...       ...       ...
# 34852       6,543.00      6.30  Maribyrnong City Council      4.00      1.00
# 34853       6,543.00      6.30  Maribyrnong City Council      2.00      2.00
# 34854       6,543.00      6.30  Maribyrnong City Council      2.00      1.00
# 34855       6,543.00      6.30  Maribyrnong City Council       NaN       NaN
# 34856       6,543.00      6.30  Maribyrnong City Council      2.00      1.00
#
#        Car  Landsize  BuildingArea        Price
# 0     1.00    126.00           NaN          NaN
# 1     1.00    202.00           NaN 1,480,000.00
# 2     0.00    156.00         79.00 1,035,000.00
# 3     1.00      0.00           NaN          NaN
# 4     0.00    134.00        150.00 1,465,000.00
# ...    ...       ...           ...          ...
# 34852 3.00    593.00           NaN 1,480,000.00
# 34853 1.00     98.00        104.00   888,000.00
# 34854 2.00    220.00        120.00   705,000.00
# 34855  NaN       NaN           NaN 1,140,000.00
# 34856 0.00    250.00        103.00 1,020,000.00
#
# [34857 rows x 15 columns]

# %% [markdown]
# ### Checking for Nan values

# %%
df.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Regionname           3
# Propertycount        3
# Distance             1
# CouncilArea          3
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# Price             7610
# dtype: int64

# %%
# Some feature's missing values can be treated as zero (another class for NA values or absence of that feature)
# like 0 for Propertycount, Bedroom2 will refer to other class of NA values
# like 0 for Car feature will mean that there's no car parking feature with house
cols_to_fill_zero = ['Propertycount', 'Distance', 'Bedroom2', 'Bathroom', 'Car']
df[cols_to_fill_zero] = df[cols_to_fill_zero].fillna(0)
df
# Out:
# C:\Users\kshit\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:3636: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#            Suburb  Rooms Type Method        SellerG             Regionname  \
# 0      Abbotsford      2    h     SS         Jellis  Northern Metropolitan
# 1      Abbotsford      2    h      S         Biggin  Northern Metropolitan
# 2      Abbotsford      2    h      S         Biggin  Northern Metropolitan
# 3      Abbotsford      3    u     VB         Rounds  Northern Metropolitan
# 4      Abbotsford      3    h     SP         Biggin  Northern Metropolitan
# ...           ...    ...  ...    ...            ...                    ...
# 34852  Yarraville      4    h     PI            Jas   Western Metropolitan
# 34853  Yarraville      2    h     SP        Sweeney   Western Metropolitan
# 34854  Yarraville      2    t      S            Jas   Western Metropolitan
# 34855  Yarraville      3    h     SP  hockingstuart   Western Metropolitan
# 34856  Yarraville      2    h     PI             RW   Western Metropolitan
#
#        Propertycount  Distance               CouncilArea  Bedroom2  Bathroom  \
# 0           4,019.00      2.50        Yarra City Council      2.00      1.00
# 1           4,019.00      2.50        Yarra City Council      2.00      1.00
# 2           4,019.00      2.50        Yarra City Council      2.00      1.00
# 3           4,019.00      2.50        Yarra City Council      3.00      2.00
# 4           4,019.00      2.50        Yarra City Council      3.00      2.00
# ...              ...       ...                       ...       ...       ...
# 34852       6,543.00      6.30  Maribyrnong City Council      4.00      1.00
# 34853       6,543.00      6.30  Maribyrnong City Council      2.00      2.00
# 34854       6,543.00      6.30  Maribyrnong City Council      2.00      1.00
# 34855       6,543.00      6.30  Maribyrnong City Council      0.00      0.00
# 34856       6,543.00      6.30  Maribyrnong City Council      2.00      1.00
#
#        Car  Landsize  BuildingArea        Price
# 0     1.00    126.00           NaN          NaN
# 1     1.00    202.00           NaN 1,480,000.00
# 2     0.00    156.00         79.00 1,035,000.00
# 3     1.00      0.00           NaN          NaN
# 4     0.00    134.00        150.00 1,465,000.00
# ...    ...       ...           ...          ...
# 34852 3.00    593.00           NaN 1,480,000.00
# 34853 1.00     98.00        104.00   888,000.00
# 34854 2.00    220.00        120.00   705,000.00
# 34855 0.00       NaN           NaN 1,140,000.00
# 34856 0.00    250.00        103.00 1,020,000.00
#
# [34857 rows x 15 columns]

# %%
# other continuous features can be imputed with mean for faster results since our focus is on Reducing overfitting
# using Lasso and Ridge Regression
df['Landsize'] = df['Landsize'].fillna(df.Landsize.mean())
df['BuildingArea'] = df['BuildingArea'].fillna(df.BuildingArea.mean())
# Out:
# C:\Users\kshit\AppData\Local\Temp/ipykernel_2220/2873504457.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Landsize'] = df['Landsize'].fillna(df.Landsize.mean())
# C:\Users\kshit\AppData\Local\Temp/ipykernel_2220/2873504457.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BuildingArea'] = df['BuildingArea'].fillna(df.BuildingArea.mean())

# %%
df
# Out:
#            Suburb  Rooms Type Method        SellerG             Regionname  \
# 0      Abbotsford      2    h     SS         Jellis  Northern Metropolitan
# 1      Abbotsford      2    h      S         Biggin  Northern Metropolitan
# 2      Abbotsford      2    h      S         Biggin  Northern Metropolitan
# 3      Abbotsford      3    u     VB         Rounds  Northern Metropolitan
# 4      Abbotsford      3    h     SP         Biggin  Northern Metropolitan
# ...           ...    ...  ...    ...            ...                    ...
# 34852  Yarraville      4    h     PI            Jas   Western Metropolitan
# 34853  Yarraville      2    h     SP        Sweeney   Western Metropolitan
# 34854  Yarraville      2    t      S            Jas   Western Metropolitan
# 34855  Yarraville      3    h     SP  hockingstuart   Western Metropolitan
# 34856  Yarraville      2    h     PI             RW   Western Metropolitan
#
#        Propertycount  Distance               CouncilArea  Bedroom2  Bathroom  \
# 0           4,019.00      2.50        Yarra City Council      2.00      1.00
# 1           4,019.00      2.50        Yarra City Council      2.00      1.00
# 2           4,019.00      2.50        Yarra City Council      2.00      1.00
# 3           4,019.00      2.50        Yarra City Council      3.00      2.00
# 4           4,019.00      2.50        Yarra City Council      3.00      2.00
# ...              ...       ...                       ...       ...       ...
# 34852       6,543.00      6.30  Maribyrnong City Council      4.00      1.00
# 34853       6,543.00      6.30  Maribyrnong City Council      2.00      2.00
# 34854       6,543.00      6.30  Maribyrnong City Council      2.00      1.00
# 34855       6,543.00      6.30  Maribyrnong City Council      0.00      0.00
# 34856       6,543.00      6.30  Maribyrnong City Council      2.00      1.00
#
#        Car  Landsize  BuildingArea        Price
# 0     1.00    126.00        160.26          NaN
# 1     1.00    202.00        160.26 1,480,000.00
# 2     0.00    156.00         79.00 1,035,000.00
# 3     1.00      0.00        160.26          NaN
# 4     0.00    134.00        150.00 1,465,000.00
# ...    ...       ...           ...          ...
# 34852 3.00    593.00        160.26 1,480,000.00
# 34853 1.00     98.00        104.00   888,000.00
# 34854 2.00    220.00        120.00   705,000.00
# 34855 0.00    593.60        160.26 1,140,000.00
# 34856 0.00    250.00        103.00 1,020,000.00
#
# [34857 rows x 15 columns]

# %%
# Since the price column is our target variable, we can not just fill it with mean or median, we need and accurate model, so we drop all of them.
df.dropna(inplace=True)
df.shape
# Out:
# C:\Users\kshit\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# (27244, 15)

# %%
df = pd.get_dummies(df, drop_first=True)
df
# Out:
#        Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 1          2       4,019.00      2.50      2.00      1.00 1.00    202.00
# 2          2       4,019.00      2.50      2.00      1.00 0.00    156.00
# 4          3       4,019.00      2.50      3.00      2.00 0.00    134.00
# 5          3       4,019.00      2.50      3.00      2.00 1.00     94.00
# 6          4       4,019.00      2.50      3.00      1.00 2.00    120.00
# ...      ...            ...       ...       ...       ...  ...       ...
# 34852      4       6,543.00      6.30      4.00      1.00 3.00    593.00
# 34853      2       6,543.00      6.30      2.00      2.00 1.00     98.00
# 34854      2       6,543.00      6.30      2.00      1.00 2.00    220.00
# 34855      3       6,543.00      6.30      0.00      0.00 0.00    593.60
# 34856      2       6,543.00      6.30      2.00      1.00 0.00    250.00
#
#        BuildingArea        Price  Suburb_Aberfeldie  ...  \
# 1            160.26 1,480,000.00                  0  ...
# 2             79.00 1,035,000.00                  0  ...
# 4            150.00 1,465,000.00                  0  ...
# 5            160.26   850,000.00                  0  ...
# 6            142.00 1,600,000.00                  0  ...
# ...             ...          ...                ...  ...
# 34852        160.26 1,480,000.00                  0  ...
# 34853        104.00   888,000.00                  0  ...
# 34854        120.00   705,000.00                  0  ...
# 34855        160.26 1,140,000.00                  0  ...
# 34856        103.00 1,020,000.00                  0  ...
#
#        CouncilArea_Moorabool Shire Council  CouncilArea_Moreland City Council  \
# 1                                        0                                  0
# 2                                        0                                  0
# 4                                        0                                  0
# 5                                        0                                  0
# 6                                        0                                  0
# ...                                    ...                                ...
# 34852                                    0                                  0
# 34853                                    0                                  0
# 34854                                    0                                  0
# 34855                                    0                                  0
# 34856                                    0                                  0
#
#        CouncilArea_Nillumbik Shire Council  \
# 1                                        0
# 2                                        0
# 4                                        0
# 5                                        0
# 6                                        0
# ...                                    ...
# 34852                                    0
# 34853                                    0
# 34854                                    0
# 34855                                    0
# 34856                                    0
#
#        CouncilArea_Port Phillip City Council  \
# 1                                          0
# 2                                          0
# 4                                          0
# 5                                          0
# 6                                          0
# ...                                      ...
# 34852                                      0
# 34853                                      0
# 34854                                      0
# 34855                                      0
# 34856                                      0
#
#        CouncilArea_Stonnington City Council  \
# 1                                         0
# 2                                         0
# 4                                         0
# 5                                         0
# 6                                         0
# ...                                     ...
# 34852                                     0
# 34853                                     0
# 34854                                     0
# 34855                                     0
# 34856                                     0
#
#        CouncilArea_Whitehorse City Council  \
# 1                                        0
# 2                                        0
# 4                                        0
# 5                                        0
# 6                                        0
# ...                                    ...
# 34852                                    0
# 34853                                    0
# 34854                                    0
# 34855                                    0
# 34856                                    0
#
#        CouncilArea_Whittlesea City Council  CouncilArea_Wyndham City Council  \
# 1                                        0                                 0
# 2                                        0                                 0
# 4                                        0                                 0
# 5                                        0                                 0
# 6                                        0                                 0
# ...                                    ...                               ...
# 34852                                    0                                 0
# 34853                                    0                                 0
# 34854                                    0                                 0
# 34855                                    0                                 0
# 34856                                    0                                 0
#
#        CouncilArea_Yarra City Council  CouncilArea_Yarra Ranges Shire Council
# 1                                   1                                       0
# 2                                   1                                       0
# 4                                   1                                       0
# 5                                   1                                       0
# 6                                   1                                       0
# ...                               ...                                     ...
# 34852                               0                                       0
# 34853                               0                                       0
# 34854                               0                                       0
# 34855                               0                                       0
# 34856                               0                                       0
#
# [27244 rows x 745 columns]

# %%
X = df.drop('Price', axis='columns')
y = df.Price
# Out:
# 1       1,480,000.00
# 2       1,035,000.00
# 4       1,465,000.00
# 5         850,000.00
# 6       1,600,000.00
#             ...
# 34852   1,480,000.00
# 34853     888,000.00
# 34854     705,000.00
# 34855   1,140,000.00
# 34856   1,020,000.00
# Name: Price, Length: 27244, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test
